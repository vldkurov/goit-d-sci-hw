# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ### CNN

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers.legacy import Adam

# load dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()

# reshape dataset to have a single channel
trainX = trainX.reshape((trainX.shape[0], 28, 28, 1))
testX = testX.reshape((testX.shape[0], 28, 28, 1))

# build the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dense(10, activation='softmax'))

# compile the model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# fit the model
history=model.fit(trainX, trainy, epochs=10, batch_size=32, validation_data=(testX, testy))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.6972 - accuracy: 0.8457 - val_loss: 0.3461 - val_accuracy: 0.8780
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2884 - accuracy: 0.8949 - val_loss: 0.3376 - val_accuracy: 0.8806
# Epoch 3/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2532 - accuracy: 0.9061 - val_loss: 0.3394 - val_accuracy: 0.8835
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2321 - accuracy: 0.9137 - val_loss: 0.3310 - val_accuracy: 0.8879
# Epoch 5/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2110 - accuracy: 0.9205 - val_loss: 0.3568 - val_accuracy: 0.8880
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1974 - accuracy: 0.9252 - val_loss: 0.3606 - val_accuracy: 0.8926
# Epoch 7/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1777 - accuracy: 0.9334 - val_loss: 0.3635 - val_accuracy: 0.8920
# Epoch 8/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1677 - accuracy: 0.9373 - val_loss: 0.3696 - val_accuracy: 0.8931
# Epoch 9/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1512 - accuracy: 0.9431 - val_loss: 0.4224 - val_accuracy: 0.8884
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1464 - accuracy: 0.9441 - val_loss: 0.4324 - val_accuracy: 0.8932

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# "History" object keeps the history of loss and metric values in history.history:
history_dict = history.history

# Plot Training and validation loss:

loss_values = history_dict['loss']  # Loss values for training
val_loss_values = history_dict['val_loss'] # Loss values for validation
epochs = range(1, len(loss_values) + 1) # X-axis values

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(epochs, loss_values, 'g', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Training and validation accuracy:

acc_values = history_dict['accuracy']  # accuracy values for training
val_acc_values = history_dict['val_accuracy'] # accuracy values for validation

plt.subplot(1,2,2)
plt.plot(epochs, acc_values, 'g', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(testX, testy)
print('\nTest loss: %.2f' % loss)
print('Test accuracy: %.2f' % accuracy)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.4324 - accuracy: 0.8932
#
# Test loss: 0.43
# Test accuracy: 0.89

# %% [markdown]
# ### VGG16

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers.legacy import Adam
import numpy as np
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array

# load the VGG16 model without the final layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# make the weights of the base model non-trainable
for layer in base_model.layers:
    layer.trainable = False

# add your own final layers
x = Flatten()(base_model.output)
x = Dense(100, activation='relu')(x)
predictions = Dense(10, activation='softmax')(x)

# create a new model
model = Model(inputs=base_model.input, outputs=predictions)

# compile and fit the model
model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# function to resize and convert images
def process_images(X):
    X_processed = []
    for image in X:
        # convert array to image
        img = array_to_img(image, scale=False)
        # resize the image to 32x32
        img = img.resize((32, 32))
        # convert back to array
        img_array = img_to_array(img)
        # convert single channel grayscale to three channel RGB
        img_array = np.repeat(img_array, 3, axis=2)
        X_processed.append(img_array)
    return np.array(X_processed)

# reshape the images in trainX and testX
trainX = process_images(trainX)
testX = process_images(testX)

history=model.fit(trainX, trainy, epochs=50, batch_size=32, validation_data=(testX, testy))
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 147s 79ms/step - loss: 0.9254 - accuracy: 0.7770 - val_loss: 0.5284 - val_accuracy: 0.8157
# Epoch 2/50
# 1875/1875 [==============================] - 146s 78ms/step - loss: 0.4520 - accuracy: 0.8368 - val_loss: 0.5039 - val_accuracy: 0.8189
# Epoch 3/50
# 1875/1875 [==============================] - 147s 79ms/step - loss: 0.4112 - accuracy: 0.8501 - val_loss: 0.4725 - val_accuracy: 0.8290
# Epoch 4/50
# 1875/1875 [==============================] - 148s 79ms/step - loss: 0.3841 - accuracy: 0.8582 - val_loss: 0.4484 - val_accuracy: 0.8440
# Epoch 5/50
# 1875/1875 [==============================] - 147s 79ms/step - loss: 0.3670 - accuracy: 0.8655 - val_loss: 0.4413 - val_accuracy: 0.8432
# Epoch 6/50
# 1875/1875 [==============================] - 150s 80ms/step - loss: 0.3468 - accuracy: 0.8714 - val_loss: 0.4622 - val_accuracy: 0.8405
# Epoch 7/50
# 1875/1875 [==============================] - 146s 78ms/step - loss: 0.3355 - accuracy: 0.8747 - val_loss: 0.4575 - val_accuracy: 0.8473
# Epoch 8/50
# 1875/1875 [==============================] - 147s 78ms/step - loss: 0.3195 - accuracy: 0.8804 - val_loss: 0.4822 - val_accuracy: 0.8426
# Epoch 9/50
# 1875/1875 [==============================] - 147s 79ms/step - loss: 0.3082 - accuracy: 0.8857 - val_loss: 0.4633 - val_accuracy: 0.8444
# Epoch 10/50
# 1875/1875 [==============================] - 147s 79ms/step - loss: 0.2966 - accuracy: 0.8895 - val_loss: 0.4838 - val_accuracy: 0.8481
# Epoch 11/50
# 1875/1875 [==============================] - 148s 79ms/step - loss: 0.2866 - accuracy: 0.8921 - val_loss: 0.4857 - val_accuracy: 0.8427
# Epoch 12/50
# 1875/1875 [==============================] - 148s 79ms/step - loss: 0.2804 - accuracy: 0.8947 - val_loss: 0.4979 - val_accuracy: 0.8473
# Epoch 13/50
# 1875/1875 [==============================] - 150s 80ms/step - loss: 0.2696 - accuracy: 0.8995 - val_loss: 0.5053 - val_accuracy: 0.8470
# Epoch 14/50
# 1875/1875 [==============================] - 149s 79ms/step - loss: 0.2658 - accuracy: 0.9002 - val_loss: 0.5209 - val_accuracy: 0.8421
# Epoch 15/50
# 1875/1875 [==============================] - 151s 80ms/step - loss: 0.2574 - accuracy: 0.9039 - val_loss: 0.5331 - val_accuracy: 0.8493
# Epoch 16/50
# 1875/1875 [==============================] - 153s 81ms/step - loss: 0.2467 - accuracy: 0.9070 - val_loss: 0.5427 - val_accuracy: 0.8470
# Epoch 17/50
# 1875/1875 [==============================] - 166s 88ms/step - loss: 0.2418 - accuracy: 0.9099 - val_loss: 0.5522 - val_accuracy: 0.8516
# Epoch 18/50
# 1875/1875 [==============================] - 167s 89ms/step - loss: 0.2410 - accuracy: 0.9099 - val_loss: 0.5860 - val_accuracy: 0.8413
# Epoch 19/50
# 1875/1875 [==============================] - 163s 87ms/step - loss: 0.2336 - accuracy: 0.9137 - val_loss: 0.5921 - val_accuracy: 0.8442
# Epoch 20/50
# 1875/1875 [==============================] - 163s 87ms/step - loss: 0.2308 - accuracy: 0.9136 - val_loss: 0.6022 - val_accuracy: 0.8465
# Epoch 21/50
# 1875/1875 [==============================] - 165s 88ms/step - loss: 0.2241 - accuracy: 0.9153 - val_loss: 0.6138 - val_accuracy: 0.8486
# Epoch 22/50
# 1875/1875 [==============================] - 162s 86ms/step - loss: 0.2211 - accuracy: 0.9179 - val_loss: 0.6084 - val_accuracy: 0.8484
# Epoch 23/50
# 1875/1875 [==============================] - 161s 86ms/step - loss: 0.2190 - accuracy: 0.9176 - val_loss: 0.6353 - val_accuracy: 0.8467
# Epoch 24/50
# 1875/1875 [==============================] - 163s 87ms/step - loss: 0.2138 - accuracy: 0.9197 - val_loss: 0.6712 - val_accuracy: 0.8393
# Epoch 25/50
# 1875/1875 [==============================] - 168s 90ms/step - loss: 0.2106 - accuracy: 0.9212 - val_loss: 0.6900 - val_accuracy: 0.8452
# Epoch 26/50
# 1875/1875 [==============================] - 159s 85ms/step - loss: 0.2058 - accuracy: 0.9232 - val_loss: 0.7090 - val_accuracy: 0.8414
# Epoch 27/50
# 1875/1875 [==============================] - 161s 86ms/step - loss: 0.2044 - accuracy: 0.9233 - val_loss: 0.6866 - val_accuracy: 0.8469
# Epoch 28/50
# 1875/1875 [==============================] - 162s 86ms/step - loss: 0.2014 - accuracy: 0.9244 - val_loss: 0.6968 - val_accuracy: 0.8420
# Epoch 29/50
# 1875/1875 [==============================] - 156s 83ms/step - loss: 0.1981 - accuracy: 0.9251 - val_loss: 0.7377 - val_accuracy: 0.8447
# Epoch 30/50
# 1875/1875 [==============================] - 151s 81ms/step - loss: 0.1945 - accuracy: 0.9273 - val_loss: 0.7370 - val_accuracy: 0.8453
# Epoch 31/50
# 1875/1875 [==============================] - 162s 87ms/step - loss: 0.1942 - accuracy: 0.9276 - val_loss: 0.7563 - val_accuracy: 0.8433
# Epoch 32/50
# 1875/1875 [==============================] - 231s 123ms/step - loss: 0.1920 - accuracy: 0.9275 - val_loss: 0.8017 - val_accuracy: 0.8432
# Epoch 33/50
# 1875/1875 [==============================] - 192s 103ms/step - loss: 0.1879 - accuracy: 0.9292 - val_loss: 0.7469 - val_accuracy: 0.8458
# Epoch 34/50
# 1875/1875 [==============================] - 170s 91ms/step - loss: 0.1812 - accuracy: 0.9314 - val_loss: 0.8145 - val_accuracy: 0.8415
# Epoch 35/50
# 1875/1875 [==============================] - 157s 84ms/step - loss: 0.1829 - accuracy: 0.9308 - val_loss: 0.8069 - val_accuracy: 0.8416
# Epoch 36/50
# 1875/1875 [==============================] - 158s 84ms/step - loss: 0.1762 - accuracy: 0.9340 - val_loss: 0.8522 - val_accuracy: 0.8396
# Epoch 37/50
# 1875/1875 [==============================] - 158s 84ms/step - loss: 0.1799 - accuracy: 0.9328 - val_loss: 0.8505 - val_accuracy: 0.8405
# Epoch 38/50
# 1875/1875 [==============================] - 160s 85ms/step - loss: 0.1730 - accuracy: 0.9351 - val_loss: 0.8857 - val_accuracy: 0.8421
# Epoch 39/50
# 1875/1875 [==============================] - 159s 85ms/step - loss: 0.1773 - accuracy: 0.9336 - val_loss: 0.9137 - val_accuracy: 0.8401
# Epoch 40/50
# 1875/1875 [==============================] - 160s 85ms/step - loss: 0.1756 - accuracy: 0.9345 - val_loss: 0.8802 - val_accuracy: 0.8421
# Epoch 41/50
# 1875/1875 [==============================] - 159s 85ms/step - loss: 0.1681 - accuracy: 0.9372 - val_loss: 0.9224 - val_accuracy: 0.8429
# Epoch 42/50
# 1875/1875 [==============================] - 1345s 717ms/step - loss: 0.1688 - accuracy: 0.9369 - val_loss: 0.9493 - val_accuracy: 0.8465
# Epoch 43/50
# 1875/1875 [==============================] - 1269s 677ms/step - loss: 0.1682 - accuracy: 0.9365 - val_loss: 0.9978 - val_accuracy: 0.8386
# Epoch 44/50
# 1875/1875 [==============================] - 1563s 834ms/step - loss: 0.1627 - accuracy: 0.9400 - val_loss: 0.9422 - val_accuracy: 0.8424
# Epoch 45/50
# 1875/1875 [==============================] - 181s 97ms/step - loss: 0.1630 - accuracy: 0.9396 - val_loss: 1.0221 - val_accuracy: 0.8403
# Epoch 46/50
# 1875/1875 [==============================] - 2016s 1s/step - loss: 0.1645 - accuracy: 0.9384 - val_loss: 0.9732 - val_accuracy: 0.8411
# Epoch 47/50
# 1875/1875 [==============================] - 1158s 618ms/step - loss: 0.1623 - accuracy: 0.9391 - val_loss: 1.0183 - val_accuracy: 0.8405
# Epoch 48/50
# 1875/1875 [==============================] - 158s 84ms/step - loss: 0.1567 - accuracy: 0.9418 - val_loss: 1.0443 - val_accuracy: 0.8339
# Epoch 49/50
# 1875/1875 [==============================] - 155s 83ms/step - loss: 0.1611 - accuracy: 0.9408 - val_loss: 1.0278 - val_accuracy: 0.8369
# Epoch 50/50
# 1875/1875 [==============================] - 164s 88ms/step - loss: 0.1537 - accuracy: 0.9421 - val_loss: 1.0750 - val_accuracy: 0.8372

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# "History" object keeps the history of loss and metric values in history.history:
history_dict = history.history

# Plot Training and validation loss:

loss_values = history_dict['loss']  # Loss values for training
val_loss_values = history_dict['val_loss'] # Loss values for validation
epochs = range(1, len(loss_values) + 1) # X-axis values

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.plot(epochs, loss_values, 'g', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Training and validation accuracy:

acc_values = history_dict['accuracy']  # accuracy values for training
val_acc_values = history_dict['val_accuracy'] # accuracy values for validation

plt.subplot(1,2,2)
plt.plot(epochs, acc_values, 'g', label='Training accuracy')
plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
loss, accuracy = model.evaluate(testX, testy)
print('\nTest loss: %.2f' % loss)
print('Test accuracy: %.2f' % accuracy)
# Out:
# 313/313 [==============================] - 26s 83ms/step - loss: 1.0750 - accuracy: 0.8372
#
# Test loss: 1.08
# Test accuracy: 0.84

# %%
model.save('./model/vgg16_model_ii.h5')

# %% [markdown]
# ### Conclusion
#
# В заключение, использование weights от pre-trained моделей (как VGG16) может иметь преимущества в части экономии времени расчетов и ресурсов памяти, однако стоит обращать внимание на соответствие начальных параметров обучения модели конечной цели задачи. Transfer learning работает лучше всего, когда входные данные аналогичны данным, на которых обучалась предварительно обученная модель. В нашем случае, используя VGG16 (которые являются предварительно-тренированными на RGB изображениях) для изображений в оттенках серого от fashion_MNIST dataset не может быть оптимальным выбором. Для задач с изображениями в оттенках серого, возможно, стоит изучить предварительно обученные сети, обученные на аналогичных наборах данных в оттенках серого, или рассмотреть возможность обучения более подходящих моделей с нуля.
